# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from scipy import stats
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ***
# ## loading data

# %%
features = [f"f_{i}" for i in range(300)]

features = pd.read_parquet("../input/ump-dataset/train.parquet", columns=features)
display(features)

target = pd.read_parquet("../input/ump-dataset/train.parquet", columns=["target",])
display(target)

time = pd.read_parquet("../input/ump-dataset/train.parquet", columns=["time_id",])
display(time)
# Out:
#               f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0        0.932573  0.113691 -0.402206  0.378386 -0.203938 -0.413469  0.965623
# 1        0.810802 -0.514115  0.742368 -0.616673 -0.194255  1.771210  1.428127
# 2        0.393974  0.615937  0.567806 -0.607963  0.068883 -1.083155  0.979656
# 3       -2.343535 -0.011870  1.874606 -0.606346 -0.586827 -0.815737  0.778096
# 4        0.842057 -0.262993  2.330030 -0.583422 -0.618392 -0.742814 -0.946789
# ...           ...       ...       ...       ...       ...       ...       ...
# 3141405  0.093530 -0.720275 -0.345497 -0.438781 -0.166972 -0.437182  1.475746
# 3141406 -1.344935 -0.199987 -0.107702 -0.454677 -0.221914 -0.141174 -1.498235
# 3141407  0.979489 -1.110491  1.006980 -0.467307 -0.159549  1.355671  0.150812
# 3141408 -2.565332  0.320301  0.076600  1.380182 -0.155366 -0.689000  0.381069
# 3141409 -0.089557  0.190229 -0.548256  0.151205  0.079773  0.447962  1.014983
#
#               f_7       f_8       f_9  ...     f_290     f_291     f_292  \
# 0        1.230508  0.114809 -2.012777  ...  0.366028 -1.095620  0.200075
# 1        1.134144  0.114809 -0.219201  ... -0.154193  0.912726 -0.734579
# 2       -1.125681  0.114809 -1.035376  ... -0.138020  0.912726 -0.551904
# 3        0.298990  0.114809 -1.176410  ...  0.382201  0.912726 -0.266359
# 4        1.230508  0.114809 -0.005858  ... -0.170365  0.912726 -0.741355
# ...           ...       ...       ...  ...       ...       ...       ...
# 3141405  1.284423  0.056425 -1.433681  ... -0.285908 -1.232434 -0.660579
# 3141406  1.373834  0.056425 -1.211572  ...  0.184517 -1.232434 -0.670493
# 3141407 -0.088923  0.056425  0.996380  ... -0.756332 -1.232434  0.820784
# 3141408 -1.324759  0.056425 -1.111730  ... -0.756332 -1.232434  0.133074
# 3141409 -1.324759  0.056425 -1.952123  ... -0.317095  0.811402  3.271590
#
#             f_293     f_294     f_295     f_296     f_297     f_298     f_299
# 0        0.819155  0.941183 -0.086764 -1.087009 -1.044826 -0.287605  0.321566
# 1        0.819155  0.941183 -0.387617 -1.087009 -0.929529 -0.974060 -0.343624
# 2       -1.220772 -1.060166 -0.219097 -1.087009 -0.612428 -0.113944  0.243608
# 3       -1.220772  0.941183 -0.609113  0.104928 -0.783423  1.151730 -0.773309
# 4       -1.220772  0.941183 -0.588445  0.104928  0.753279  1.345611 -0.737624
# ...           ...       ...       ...       ...       ...       ...       ...
# 3141405  0.875537  0.421628 -0.428097 -0.075548 -0.533092 -0.193732 -0.581394
# 3141406  0.875537  0.421628 -0.729949 -1.514277  0.013145 -0.890270 -0.589705
# 3141407 -1.142157  0.421628 -0.363329  1.363181 -0.079106 -1.580124 -0.297625
# 3141408 -1.142157  0.421628 -0.375288 -1.514277 -0.973762  0.608647 -0.372040
# 3141409  0.875537  0.421628 -0.170709  1.363181 -0.563314  0.669586  0.456400
#
# [3141410 rows x 300 columns]
#            target
# 0       -0.300875
# 1       -0.231040
# 2        0.568807
# 3       -1.064780
# 4       -0.531940
# ...           ...
# 3141405  0.033600
# 3141406 -0.223264
# 3141407 -0.559415
# 3141408  0.009599
# 3141409  1.212112
#
# [3141410 rows x 1 columns]
#          time_id
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3141405     1219
# 3141406     1219
# 3141407     1219
# 3141408     1219
# 3141409     1219
#
# [3141410 rows x 1 columns]

# %%
time_ids = np.sort(time.time_id.unique())
len(time_ids)
# Out:
# 1211

# %%
n_time_steps = len(time_ids)
print("time steps:", n_time_steps)

valid_prop = 0.1
valid_size = int(0.1 * n_time_steps)
print("valid size:", valid_size)
# Out:
# time steps: 1211
# valid size: 121

# %%
# train-valid splits
n_splits = 3
end_idx = n_time_steps 

splits = list()

for start_idx in np.arange(1211, 0, -valid_size)[1:n_splits+1]:
    valid_time_ids = time_ids[start_idx:end_idx]
    train_time_end = time_ids[start_idx]-1
    end_idx = start_idx
    
    train_idx = time.query("time_id <= @train_time_end").index
    valid_idx = time.query("time_id in @valid_time_ids").index
    splits.append((train_idx,valid_idx))

# %%
import gc
gc.collect()
# Out:
# 102

# %% [markdown]
# ***
# ## model training: finding number of iterations

# %%
def pearsonr(preds: np.array, dset: lgb.Dataset):
    """
    Helper function to compute Pearson correlation 
    on validation dataset for LightGBM as tracking metric.
    Args:
        preds: 1d-array with the model predictions
        dset: LightGBM dataset with the labels
    Returs:
        Tuple with the corresponding output
    """
    labels = dset.get_label()
    return 'pearsonr', stats.pearsonr(preds, labels)[0], True

# %%
# 0.89471
#model_params = dict(
#    objective="mse",
#    metric="rmse",
#    num_leaves=32,
#    learning_rate=0.05,
#    feature_fraction=0.5,
#    bagging_fraction=0.8,
#    force_col_wise=True,
#    seed=19
#)

# %%
model_params = {
    'objective': 'mse',
    'metric': 'rmse',
    'num_leaves': 55,
    'learning_rate': 0.05,
    'feature_fraction': 0.616,
    'bagging_fraction': 0.8,
    'force_col_wise': True,
    'feature_pre_filter': False,
    'lambda_l1': 3.563444727371679,
    'lambda_l2': 0.30026771722107604,
    'bagging_freq': 0,
    'min_child_samples': 100,
}

# %%
#model_params = dict(
#    boosting='dart',
#    drop_rate=0.1,
#    max_drop=20,
#    skip_drop=0.66,
#    #extra_trees=True,
#    objective="mse",
#    metric="rmse",
#    num_leaves=32,
#    learning_rate=0.05,
#    feature_fraction=0.5,
#    bagging_fraction=0.6,
#    force_col_wise=True,
#    min_data_in_leaf=100,
#    seed=19,
#    bin_construct_sample_cnt=int(1e10),
#)

# %%
pretrain = True

if pretrain:
    
    models = list()

    for train_idx,valid_idx in splits:

        train_dset = lgb.Dataset(
            data=features.loc[train_idx,:],
            label=target.loc[train_idx,"target"].values,
            free_raw_data=True
        )
        valid_dset = lgb.Dataset(
            data=features.loc[valid_idx,:],
            label=target.loc[valid_idx,"target"].values,
            free_raw_data=True
        )

        model = lgb.train(
            params=model_params,
            train_set=train_dset,
            num_boost_round=1000,
            valid_sets=[valid_dset,],
            early_stopping_rounds=50,
            verbose_eval=20,
            feval=pearsonr,
        )
        models.append(model)

        lgb.plot_importance(model, figsize=(8,15), importance_type="split", max_num_features=30)
        lgb.plot_importance(model, figsize=(8,15), importance_type="gain", max_num_features=30)
        plt.show()
        
        # residual analysis on oof predictions
        oof = target.loc[valid_idx,:].copy()
        oof["time_id"] = time.loc[valid_idx,"time_id"]
        oof["pred"] = model.predict(features.loc[valid_idx,:])
        oof["target_abs"] = oof.eval("abs(target)")
        oof["dev"] = oof.eval("abs(target-pred)")

        corrs = oof.groupby("time_id").apply(lambda x: stats.pearsonr(x.target, x.pred)[0])
        corr_mean = corrs.mean()
        error = oof.groupby("time_id").apply(lambda x: np.sqrt(np.mean((x.target-x.pred)**2)))
        error_mean = error.mean()

        plt.figure(figsize=(18,8))
        plt.subplot(1,2,1)
        corrs.plot()
        plt.axhline(y=corr_mean, color='r', linestyle='-', label=f"corr={corr_mean}")
        plt.grid()
        plt.ylabel("corr")
        plt.legend(loc="best")
        ##
        plt.subplot(1,2,2)
        error.plot()
        plt.axhline(y=error_mean, color='r', linestyle='-', label=f"rmse={error_mean}")
        plt.grid()
        plt.ylabel("rmse")
        plt.legend(loc="best")
        plt.show()

        plt.figure(figsize=(22,8))
        ##
        plt.subplot(1,3,1)
        plt.plot(oof.sort_values("target_abs").target_abs.values, oof.sort_values("target_abs").dev.values)
        plt.xlabel("target_abs")
        plt.ylabel("deviance (abs)")
        plt.grid()
        ##
        plt.subplot(1,3,2)
        plt.plot(oof.sort_values("target").target.values, oof.sort_values("target").dev.values)
        plt.xlabel("target")
        plt.ylabel("deviance (abs)")
        plt.grid()
        ##
        plt.subplot(1,3,3)
        plt.plot(oof.sort_values("target").target.values, oof.sort_values("target").pred.values)
        plt.xlabel("target")
        plt.ylabel("pred")
        plt.grid()
        plt.show()
           
    n_iterations = int(np.mean([m.best_iteration for m in models]))
    
else:
    # best value previously found
    n_iterations = 546
    

print("n_iterations:", n_iterations)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 2740634, number of used features: 300
# [LightGBM] [Info] Start training from score -0.022338
# Training until validation scores don't improve for 50 rounds
# [20]	valid_0's rmse: 0.898583	valid_0's pearsonr: 0.123964
# [40]	valid_0's rmse: 0.897081	valid_0's pearsonr: 0.127403
# [60]	valid_0's rmse: 0.896436	valid_0's pearsonr: 0.129426
# [80]	valid_0's rmse: 0.896055	valid_0's pearsonr: 0.130757
# [100]	valid_0's rmse: 0.89584	valid_0's pearsonr: 0.131397
# [120]	valid_0's rmse: 0.895714	valid_0's pearsonr: 0.131444
# [140]	valid_0's rmse: 0.895538	valid_0's pearsonr: 0.132324
# [160]	valid_0's rmse: 0.895373	valid_0's pearsonr: 0.133232
# [180]	valid_0's rmse: 0.895323	valid_0's pearsonr: 0.133281
# [200]	valid_0's rmse: 0.895214	valid_0's pearsonr: 0.133895
# [220]	valid_0's rmse: 0.895118	valid_0's pearsonr: 0.134435
# [240]	valid_0's rmse: 0.895058	valid_0's pearsonr: 0.134732
# [260]	valid_0's rmse: 0.894973	valid_0's pearsonr: 0.135341
# [280]	valid_0's rmse: 0.894906	valid_0's pearsonr: 0.135797
# [300]	valid_0's rmse: 0.894825	valid_0's pearsonr: 0.136405
# [320]	valid_0's rmse: 0.894781	valid_0's pearsonr: 0.136735
# [340]	valid_0's rmse: 0.894698	valid_0's pearsonr: 0.137372
# [360]	valid_0's rmse: 0.894681	valid_0's pearsonr: 0.137481
# [380]	valid_0's rmse: 0.894619	valid_0's pearsonr: 0.137962
# [400]	valid_0's rmse: 0.894623	valid_0's pearsonr: 0.137932
# [420]	valid_0's rmse: 0.894638	valid_0's pearsonr: 0.13783
# [440]	valid_0's rmse: 0.89465	valid_0's pearsonr: 0.137751
# [460]	valid_0's rmse: 0.894639	valid_0's pearsonr: 0.137871
# Early stopping, best iteration is:
# [410]	valid_0's rmse: 0.894602	valid_0's pearsonr: 0.138097
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 2364296, number of used features: 300
# [LightGBM] [Info] Start training from score -0.024609
# Training until validation scores don't improve for 50 rounds
# [20]	valid_0's rmse: 0.906366	valid_0's pearsonr: 0.108964
# [40]	valid_0's rmse: 0.904932	valid_0's pearsonr: 0.116175
# [60]	valid_0's rmse: 0.90413	valid_0's pearsonr: 0.121257
# [80]	valid_0's rmse: 0.903623	valid_0's pearsonr: 0.124706
# [100]	valid_0's rmse: 0.903162	valid_0's pearsonr: 0.128088
# [120]	valid_0's rmse: 0.90285	valid_0's pearsonr: 0.130043
# [140]	valid_0's rmse: 0.902562	valid_0's pearsonr: 0.13203
# [160]	valid_0's rmse: 0.902374	valid_0's pearsonr: 0.132966
# [180]	valid_0's rmse: 0.902198	valid_0's pearsonr: 0.134074
# [200]	valid_0's rmse: 0.902069	valid_0's pearsonr: 0.134878
# [220]	valid_0's rmse: 0.901959	valid_0's pearsonr: 0.135412
# [240]	valid_0's rmse: 0.901842	valid_0's pearsonr: 0.136091
# [260]	valid_0's rmse: 0.901753	valid_0's pearsonr: 0.136592
# [280]	valid_0's rmse: 0.901685	valid_0's pearsonr: 0.136959
# [300]	valid_0's rmse: 0.901647	valid_0's pearsonr: 0.137099
# [320]	valid_0's rmse: 0.901564	valid_0's pearsonr: 0.137677
# [340]	valid_0's rmse: 0.901591	valid_0's pearsonr: 0.137323
# [360]	valid_0's rmse: 0.901578	valid_0's pearsonr: 0.137348
# Early stopping, best iteration is:
# [319]	valid_0's rmse: 0.901547	valid_0's pearsonr: 0.137832
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 1995404, number of used features: 300
# [LightGBM] [Info] Start training from score -0.026871
# Training until validation scores don't improve for 50 rounds
# [20]	valid_0's rmse: 0.940584	valid_0's pearsonr: 0.0933559
# [40]	valid_0's rmse: 0.939486	valid_0's pearsonr: 0.100448
# [60]	valid_0's rmse: 0.938874	valid_0's pearsonr: 0.10522
# [80]	valid_0's rmse: 0.938422	valid_0's pearsonr: 0.109012
# [100]	valid_0's rmse: 0.938038	valid_0's pearsonr: 0.112347
# [120]	valid_0's rmse: 0.937727	valid_0's pearsonr: 0.114904
# [140]	valid_0's rmse: 0.937444	valid_0's pearsonr: 0.117186
# [160]	valid_0's rmse: 0.937142	valid_0's pearsonr: 0.119802
# [180]	valid_0's rmse: 0.936922	valid_0's pearsonr: 0.121493
# [200]	valid_0's rmse: 0.936691	valid_0's pearsonr: 0.123354
# [220]	valid_0's rmse: 0.936567	valid_0's pearsonr: 0.124285
# [240]	valid_0's rmse: 0.936448	valid_0's pearsonr: 0.125191
# [260]	valid_0's rmse: 0.936362	valid_0's pearsonr: 0.125818
# [280]	valid_0's rmse: 0.936319	valid_0's pearsonr: 0.126121
# [300]	valid_0's rmse: 0.93626	valid_0's pearsonr: 0.126593
# [320]	valid_0's rmse: 0.936185	valid_0's pearsonr: 0.1272
# [340]	valid_0's rmse: 0.936087	valid_0's pearsonr: 0.128017
# [360]	valid_0's rmse: 0.936006	valid_0's pearsonr: 0.128694
# [380]	valid_0's rmse: 0.935893	valid_0's pearsonr: 0.1296
# [400]	valid_0's rmse: 0.935854	valid_0's pearsonr: 0.129941
# [420]	valid_0's rmse: 0.935809	valid_0's pearsonr: 0.130328
# [440]	valid_0's rmse: 0.935779	valid_0's pearsonr: 0.130602
# [460]	valid_0's rmse: 0.935719	valid_0's pearsonr: 0.131121
# [480]	valid_0's rmse: 0.935701	valid_0's pearsonr: 0.131305
# [500]	valid_0's rmse: 0.935673	valid_0's pearsonr: 0.131558
# [520]	valid_0's rmse: 0.935623	valid_0's pearsonr: 0.132002
# [540]	valid_0's rmse: 0.93558	valid_0's pearsonr: 0.132362
# [560]	valid_0's rmse: 0.935542	valid_0's pearsonr: 0.132692
# [580]	valid_0's rmse: 0.93555	valid_0's pearsonr: 0.132698
# Early stopping, best iteration is:
# [549]	valid_0's rmse: 0.935525	valid_0's pearsonr: 0.132792
# n_iterations: 426

# %% [markdown]
# ***
# ## model training

# %%
seeds = [2,7,11,19,23]
models = list()

for seed in seeds:
    model_params["seed"] = seed
    
    train_dset = lgb.Dataset(
        data=features,
        label=target.target.values,
        free_raw_data=True
    )
    #random_idx = train.sample(frac=0.2).index
    #valid_dset = lgb.Dataset(
    #    data=train.loc[random_idx,features],
    #    label=train.loc[random_idx,"target"].values,
    #    free_raw_data=True
    #)
    model = lgb.train(
        params=model_params,
        train_set=train_dset,
        num_boost_round=n_iterations,
        valid_sets=[train_dset,],
        early_stopping_rounds=10*n_iterations,
        verbose_eval=20,
        feval=pearsonr,
    )
    models.append(model)

    lgb.plot_importance(model, figsize=(8,15), importance_type="split", max_num_features=30)
    lgb.plot_importance(model, figsize=(8,15), importance_type="gain", max_num_features=30)
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 4260 rounds
# [20]	training's rmse: 0.913883	training's pearsonr: 0.137142
# [40]	training's rmse: 0.911267	training's pearsonr: 0.150652
# [60]	training's rmse: 0.909427	training's pearsonr: 0.162603
# [80]	training's rmse: 0.907867	training's pearsonr: 0.173536
# [100]	training's rmse: 0.906402	training's pearsonr: 0.184027
# [120]	training's rmse: 0.905142	training's pearsonr: 0.192405
# [140]	training's rmse: 0.903896	training's pearsonr: 0.200615
# [160]	training's rmse: 0.90273	training's pearsonr: 0.208155
# [180]	training's rmse: 0.90157	training's pearsonr: 0.215524
# [200]	training's rmse: 0.90046	training's pearsonr: 0.222125
# [220]	training's rmse: 0.899448	training's pearsonr: 0.227909
# [240]	training's rmse: 0.898444	training's pearsonr: 0.233647
# [260]	training's rmse: 0.897532	training's pearsonr: 0.238791
# [280]	training's rmse: 0.896552	training's pearsonr: 0.24413
# [300]	training's rmse: 0.895641	training's pearsonr: 0.248929
# [320]	training's rmse: 0.894797	training's pearsonr: 0.253402
# [340]	training's rmse: 0.893961	training's pearsonr: 0.25768
# [360]	training's rmse: 0.893145	training's pearsonr: 0.26196
# [380]	training's rmse: 0.892394	training's pearsonr: 0.26595
# [400]	training's rmse: 0.891653	training's pearsonr: 0.269705
# [420]	training's rmse: 0.89094	training's pearsonr: 0.273424
# Did not meet early stopping. Best iteration is:
# [426]	training's rmse: 0.890732	training's pearsonr: 0.274478
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 4260 rounds
# [20]	training's rmse: 0.913921	training's pearsonr: 0.137199
# [40]	training's rmse: 0.911261	training's pearsonr: 0.150273
# [60]	training's rmse: 0.909462	training's pearsonr: 0.162193
# [80]	training's rmse: 0.907941	training's pearsonr: 0.172905
# [100]	training's rmse: 0.906479	training's pearsonr: 0.183284
# [120]	training's rmse: 0.905198	training's pearsonr: 0.191985
# [140]	training's rmse: 0.903937	training's pearsonr: 0.200468
# [160]	training's rmse: 0.902775	training's pearsonr: 0.207775
# [180]	training's rmse: 0.901661	training's pearsonr: 0.214611
# [200]	training's rmse: 0.900561	training's pearsonr: 0.22136
# [220]	training's rmse: 0.899467	training's pearsonr: 0.227846
# [240]	training's rmse: 0.898479	training's pearsonr: 0.233478
# [260]	training's rmse: 0.89753	training's pearsonr: 0.238714
# [280]	training's rmse: 0.896572	training's pearsonr: 0.244064
# [300]	training's rmse: 0.895603	training's pearsonr: 0.249362
# [320]	training's rmse: 0.894789	training's pearsonr: 0.253651
# [340]	training's rmse: 0.893952	training's pearsonr: 0.257812
# [360]	training's rmse: 0.893155	training's pearsonr: 0.261807
# [380]	training's rmse: 0.892403	training's pearsonr: 0.265757
# [400]	training's rmse: 0.891605	training's pearsonr: 0.269829
# [420]	training's rmse: 0.890886	training's pearsonr: 0.273553
# Did not meet early stopping. Best iteration is:
# [426]	training's rmse: 0.890674	training's pearsonr: 0.274603
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 4260 rounds
# [20]	training's rmse: 0.913921	training's pearsonr: 0.136649
# [40]	training's rmse: 0.911328	training's pearsonr: 0.149406
# [60]	training's rmse: 0.909502	training's pearsonr: 0.161631
# [80]	training's rmse: 0.907852	training's pearsonr: 0.173705
# [100]	training's rmse: 0.906446	training's pearsonr: 0.183492
# [120]	training's rmse: 0.905076	training's pearsonr: 0.192912
# [140]	training's rmse: 0.90385	training's pearsonr: 0.200946
# [160]	training's rmse: 0.902725	training's pearsonr: 0.208067
# [180]	training's rmse: 0.901585	training's pearsonr: 0.215036
# [200]	training's rmse: 0.900504	training's pearsonr: 0.221693
# [220]	training's rmse: 0.899461	training's pearsonr: 0.227735
# [240]	training's rmse: 0.898426	training's pearsonr: 0.233608
# [260]	training's rmse: 0.897466	training's pearsonr: 0.238941
# [280]	training's rmse: 0.896542	training's pearsonr: 0.243963
# [300]	training's rmse: 0.895635	training's pearsonr: 0.248785
# [320]	training's rmse: 0.894789	training's pearsonr: 0.253154
# [340]	training's rmse: 0.893925	training's pearsonr: 0.25766
# [360]	training's rmse: 0.893145	training's pearsonr: 0.261671
# [380]	training's rmse: 0.892373	training's pearsonr: 0.265709
# [400]	training's rmse: 0.891636	training's pearsonr: 0.269491
# [420]	training's rmse: 0.890858	training's pearsonr: 0.273487
# Did not meet early stopping. Best iteration is:
# [426]	training's rmse: 0.890639	training's pearsonr: 0.274588
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 4260 rounds
# [20]	training's rmse: 0.913876	training's pearsonr: 0.135764
# [40]	training's rmse: 0.911301	training's pearsonr: 0.149581
# [60]	training's rmse: 0.90946	training's pearsonr: 0.162074
# [80]	training's rmse: 0.907887	training's pearsonr: 0.173269
# [100]	training's rmse: 0.906442	training's pearsonr: 0.1835
# [120]	training's rmse: 0.905131	training's pearsonr: 0.192308
# [140]	training's rmse: 0.903847	training's pearsonr: 0.20089
# [160]	training's rmse: 0.902697	training's pearsonr: 0.208149
# [180]	training's rmse: 0.901611	training's pearsonr: 0.214768
# [200]	training's rmse: 0.90053	training's pearsonr: 0.22128
# [220]	training's rmse: 0.89951	training's pearsonr: 0.227122
# [240]	training's rmse: 0.89854	training's pearsonr: 0.232666
# [260]	training's rmse: 0.897485	training's pearsonr: 0.23867
# [280]	training's rmse: 0.896545	training's pearsonr: 0.243823
# [300]	training's rmse: 0.895684	training's pearsonr: 0.248526
# [320]	training's rmse: 0.894825	training's pearsonr: 0.253101
# [340]	training's rmse: 0.894029	training's pearsonr: 0.257304
# [360]	training's rmse: 0.89324	training's pearsonr: 0.26152
# [380]	training's rmse: 0.892434	training's pearsonr: 0.265478
# [400]	training's rmse: 0.891647	training's pearsonr: 0.269448
# [420]	training's rmse: 0.890849	training's pearsonr: 0.273469
# Did not meet early stopping. Best iteration is:
# [426]	training's rmse: 0.890606	training's pearsonr: 0.274702
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 4260 rounds
# [20]	training's rmse: 0.913895	training's pearsonr: 0.136444
# [40]	training's rmse: 0.911296	training's pearsonr: 0.149768
# [60]	training's rmse: 0.909479	training's pearsonr: 0.161857
# [80]	training's rmse: 0.907865	training's pearsonr: 0.173534
# [100]	training's rmse: 0.906409	training's pearsonr: 0.183904
# [120]	training's rmse: 0.905104	training's pearsonr: 0.192699
# [140]	training's rmse: 0.903833	training's pearsonr: 0.201028
# [160]	training's rmse: 0.902687	training's pearsonr: 0.208349
# [180]	training's rmse: 0.901465	training's pearsonr: 0.215917
# [200]	training's rmse: 0.900407	training's pearsonr: 0.222332
# [220]	training's rmse: 0.899362	training's pearsonr: 0.228292
# [240]	training's rmse: 0.898383	training's pearsonr: 0.233774
# [260]	training's rmse: 0.897466	training's pearsonr: 0.238861
# [280]	training's rmse: 0.896487	training's pearsonr: 0.244129
# [300]	training's rmse: 0.895612	training's pearsonr: 0.248871
# [320]	training's rmse: 0.894737	training's pearsonr: 0.253434
# [340]	training's rmse: 0.893916	training's pearsonr: 0.257718
# [360]	training's rmse: 0.89307	training's pearsonr: 0.262244
# [380]	training's rmse: 0.892306	training's pearsonr: 0.266215
# [400]	training's rmse: 0.891491	training's pearsonr: 0.270294
# [420]	training's rmse: 0.890788	training's pearsonr: 0.273907
# Did not meet early stopping. Best iteration is:
# [426]	training's rmse: 0.890581	training's pearsonr: 0.274905

# %%
for seed,model in zip(seeds,models): 
    model.save_model(f"lgbm-seed{seed}.txt")

# %% [markdown]
# ***
# ## inference

# %%
import ubiquant
env = ubiquant.make_env()  
iter_test = env.iter_test()

# %%
features = [f"f_{i}" for i in range(300)]

for (test_df, sample_prediction_df) in iter_test:  
    preds = [model.predict(test_df[features]) for model in models]
    sample_prediction_df['target'] = np.mean(preds, axis=0)
    env.predict(sample_prediction_df) 
    display(sample_prediction_df)
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
#    row_id    target
# 0  1220_1 -0.126218
# 1  1220_2 -0.088228
#    row_id    target
# 0  1221_0 -0.081862
# 1  1221_1 -0.099691
# 2  1221_2 -0.144634
#    row_id    target
# 0  1222_0 -0.057251
# 1  1222_1 -0.067911
# 2  1222_2 -0.057505
#    row_id    target
# 0  1223_0 -0.063714

# %% [markdown]
# ***
