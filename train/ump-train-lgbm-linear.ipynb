# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from scipy import stats
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
current_env = "local"

if current_env == "local":
    data_path = "../ump-dataset"

elif current_env == "kaggle":
    data_path = "../input/ump-dataset"
    
elif current_env == "colab":
    pass

print("data_path:", data_path)
# Out:
# data_path: ../ump-dataset

# %% [markdown]
# ***
# ## loading data

# %%
features = [f"f_{i}" for i in range(300)]

features = pd.read_parquet(f"{data_path}/train.parquet", columns=features)
display(features)

target = pd.read_parquet(f"{data_path}/train.parquet", columns=["target",])
display(target)

time = pd.read_parquet(f"{data_path}/train.parquet", columns=["time_id",])
display(time)
# Out:
#               f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0        0.932573  0.113691 -0.402206  0.378386 -0.203938 -0.413469  0.965623
# 1        0.810802 -0.514115  0.742368 -0.616673 -0.194255  1.771210  1.428127
# 2        0.393974  0.615937  0.567806 -0.607963  0.068883 -1.083155  0.979656
# 3       -2.343535 -0.011870  1.874606 -0.606346 -0.586827 -0.815737  0.778096
# 4        0.842057 -0.262993  2.330030 -0.583422 -0.618392 -0.742814 -0.946789
# ...           ...       ...       ...       ...       ...       ...       ...
# 3141405  0.093530 -0.720275 -0.345497 -0.438781 -0.166972 -0.437182  1.475746
# 3141406 -1.344935 -0.199987 -0.107702 -0.454677 -0.221914 -0.141174 -1.498235
# 3141407  0.979489 -1.110491  1.006980 -0.467307 -0.159549  1.355671  0.150812
# 3141408 -2.565332  0.320301  0.076600  1.380182 -0.155366 -0.689000  0.381069
# 3141409 -0.089557  0.190229 -0.548256  0.151205  0.079773  0.447962  1.014983
#
#               f_7       f_8       f_9  ...     f_290     f_291     f_292  \
# 0        1.230508  0.114809 -2.012777  ...  0.366028 -1.095620  0.200075
# 1        1.134144  0.114809 -0.219201  ... -0.154193  0.912726 -0.734579
# 2       -1.125681  0.114809 -1.035376  ... -0.138020  0.912726 -0.551904
# 3        0.298990  0.114809 -1.176410  ...  0.382201  0.912726 -0.266359
# 4        1.230508  0.114809 -0.005858  ... -0.170365  0.912726 -0.741355
# ...           ...       ...       ...  ...       ...       ...       ...
# 3141405  1.284423  0.056425 -1.433681  ... -0.285908 -1.232434 -0.660579
# 3141406  1.373834  0.056425 -1.211572  ...  0.184517 -1.232434 -0.670493
# 3141407 -0.088923  0.056425  0.996380  ... -0.756332 -1.232434  0.820784
# 3141408 -1.324759  0.056425 -1.111730  ... -0.756332 -1.232434  0.133074
# 3141409 -1.324759  0.056425 -1.952123  ... -0.317095  0.811402  3.271590
#
#             f_293     f_294     f_295     f_296     f_297     f_298     f_299
# 0        0.819155  0.941183 -0.086764 -1.087009 -1.044826 -0.287605  0.321566
# 1        0.819155  0.941183 -0.387617 -1.087009 -0.929529 -0.974060 -0.343624
# 2       -1.220772 -1.060166 -0.219097 -1.087009 -0.612428 -0.113944  0.243608
# 3       -1.220772  0.941183 -0.609113  0.104928 -0.783423  1.151730 -0.773309
# 4       -1.220772  0.941183 -0.588445  0.104928  0.753279  1.345611 -0.737624
# ...           ...       ...       ...       ...       ...       ...       ...
# 3141405  0.875537  0.421628 -0.428097 -0.075548 -0.533092 -0.193732 -0.581394
# 3141406  0.875537  0.421628 -0.729949 -1.514277  0.013145 -0.890270 -0.589705
# 3141407 -1.142157  0.421628 -0.363329  1.363181 -0.079106 -1.580124 -0.297625
# 3141408 -1.142157  0.421628 -0.375288 -1.514277 -0.973762  0.608647 -0.372040
# 3141409  0.875537  0.421628 -0.170709  1.363181 -0.563314  0.669586  0.456400
#
# [3141410 rows x 300 columns]
#            target
# 0       -0.300875
# 1       -0.231040
# 2        0.568807
# 3       -1.064780
# 4       -0.531940
# ...           ...
# 3141405  0.033600
# 3141406 -0.223264
# 3141407 -0.559415
# 3141408  0.009599
# 3141409  1.212112
#
# [3141410 rows x 1 columns]
#          time_id
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3141405     1219
# 3141406     1219
# 3141407     1219
# 3141408     1219
# 3141409     1219
#
# [3141410 rows x 1 columns]

# %%
time_ids = np.sort(time.time_id.unique())
len(time_ids)
# Out:
# 1211

# %%
n_time_steps = len(time_ids)
print("time steps:", n_time_steps)

valid_prop = 0.1
valid_size = int(0.1 * n_time_steps)
print("valid size:", valid_size)
# Out:
# time steps: 1211
# valid size: 121

# %%
# train-valid splits
n_splits = 3
end_idx = n_time_steps 

splits = list()

for start_idx in np.arange(1211, 0, -valid_size)[1:n_splits+1]:
    valid_time_ids = time_ids[start_idx:end_idx]
    train_time_end = time_ids[start_idx]-1
    end_idx = start_idx
    
    train_idx = time.query("time_id <= @train_time_end").index
    valid_idx = time.query("time_id in @valid_time_ids").index
    splits.append((train_idx,valid_idx))

# %%
import gc
gc.collect()
# Out:
# 207

# %% [markdown]
# ***
# ## model training: finding number of iterations

# %%
def pearsonr(preds: np.array, dset: lgb.Dataset):
    """
    Helper function to compute Pearson correlation 
    on validation dataset for LightGBM as tracking metric.
    Args:
        preds: 1d-array with the model predictions
        dset: LightGBM dataset with the labels
    Returs:
        Tuple with the corresponding output
    """
    labels = dset.get_label()
    return 'pearsonr', stats.pearsonr(preds, labels)[0], True

# %%
model_params = {
    'linear_tree': True,
    'linear_lambda': 1.0,
    'objective': 'mse',
    'metric': 'rmse',
    'num_leaves': 32,
    'learning_rate': 0.05,
    'feature_fraction': 0.6,
    'bagging_fraction': 0.8,
    'force_col_wise': True,
    'feature_pre_filter': False,
    'lambda_l1': 1.0,
    'lambda_l2': 1.0,
    'bagging_freq': 0,
    'min_child_samples': 100,
    'seed': 19,
}

# %%
pretrain = True
metrics = {"corr_mean":list(), "corr_std":list(), "error_mean":list(), "error_std":list(),}

if pretrain:
    
    models = list()

    for train_idx,valid_idx in splits:

        train_dset = lgb.Dataset(
            data=features.loc[train_idx,:],
            label=target.loc[train_idx,"target"].values,
            free_raw_data=True
        )
        valid_dset = lgb.Dataset(
            data=features.loc[valid_idx,:],
            label=target.loc[valid_idx,"target"].values,
            free_raw_data=True
        )

        model = lgb.train(
            params=model_params,
            train_set=train_dset,
            num_boost_round=3000,
            valid_sets=[valid_dset,],
            early_stopping_rounds=50,
            verbose_eval=20,
            feval=pearsonr,
        )
        models.append(model)

        lgb.plot_importance(model, figsize=(8,15), importance_type="split", max_num_features=30)
        lgb.plot_importance(model, figsize=(8,15), importance_type="gain", max_num_features=30)
        plt.show()
        
        # residual analysis on oof predictions
        oof = target.loc[valid_idx,:].copy()
        oof["time_id"] = time.loc[valid_idx,"time_id"]
        oof["pred"] = model.predict(features.loc[valid_idx,:])
        oof["target_abs"] = oof.eval("abs(target)")
        oof["dev"] = oof.eval("abs(target-pred)")

        corrs = oof.groupby("time_id").apply(lambda x: stats.pearsonr(x.target, x.pred)[0])
        corr_mean = corrs.mean()
        corr_std = corrs.std()
        error = oof.groupby("time_id").apply(lambda x: np.sqrt(np.mean((x.target-x.pred)**2)))
        error_mean = error.mean()
        error_std = error.std()
        
        metrics["corr_mean"].append(corr_mean)
        metrics["corr_std"].append(corr_std)
        metrics["error_mean"].append(error_mean)
        metrics["error_std"].append(error_std)

        plt.figure(figsize=(18,8))
        plt.subplot(1,2,1)
        corrs.plot()
        plt.axhline(
            y=corr_mean, 
            color='r', 
            linestyle='-', 
            label=f"corr_mean={corr_mean:.5f} & corr_std={corr_std:.5f}"
        )
        plt.grid()
        plt.ylabel("corr")
        plt.legend(loc="best")
        ##
        plt.subplot(1,2,2)
        error.plot()
        plt.axhline(
            y=error_mean, 
            color='r', 
            linestyle='-', 
            label=f"rmse_mean={error_mean:.5f} & error_std={error_std:.5f}"
        )
        plt.grid()
        plt.ylabel("rmse")
        plt.legend(loc="best")
        plt.show()

        plt.figure(figsize=(22,8))
        ##
        plt.subplot(1,3,1)
        plt.plot(oof.sort_values("target_abs").target_abs.values, oof.sort_values("target_abs").dev.values)
        plt.xlabel("target_abs")
        plt.ylabel("deviance (abs)")
        plt.grid()
        ##
        plt.subplot(1,3,2)
        plt.plot(oof.sort_values("target").target.values, oof.sort_values("target").dev.values)
        plt.xlabel("target")
        plt.ylabel("deviance (abs)")
        plt.grid()
        ##
        plt.subplot(1,3,3)
        plt.plot(oof.sort_values("target").target.values, oof.sort_values("target").pred.values)
        plt.xlabel("target")
        plt.ylabel("pred")
        plt.grid()
        plt.show()
           
    n_iterations = int(np.mean([m.best_iteration for m in models]))
    
else:
    # best value previously found
    n_iterations = 550
    

print("n_iterations:", n_iterations)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 2740634, number of used features: 300
# [LightGBM] [Info] Start training from score -0.022338
# Training until validation scores don't improve for 50 rounds
# [20]	valid_0's rmse: 0.898401	valid_0's pearsonr: 0.122024
# [40]	valid_0's rmse: 0.896826	valid_0's pearsonr: 0.127866
# [60]	valid_0's rmse: 0.896213	valid_0's pearsonr: 0.130212
# [80]	valid_0's rmse: 0.895833	valid_0's pearsonr: 0.131925
# [100]	valid_0's rmse: 0.89562	valid_0's pearsonr: 0.132671
# [120]	valid_0's rmse: 0.89546	valid_0's pearsonr: 0.133142
# [140]	valid_0's rmse: 0.895281	valid_0's pearsonr: 0.134203
# [160]	valid_0's rmse: 0.89516	valid_0's pearsonr: 0.134784
# [180]	valid_0's rmse: 0.895141	valid_0's pearsonr: 0.134548
# [200]	valid_0's rmse: 0.89498	valid_0's pearsonr: 0.135618
# [220]	valid_0's rmse: 0.894872	valid_0's pearsonr: 0.136303
# [240]	valid_0's rmse: 0.89482	valid_0's pearsonr: 0.13659
# [260]	valid_0's rmse: 0.89479	valid_0's pearsonr: 0.136741
# [280]	valid_0's rmse: 0.8947	valid_0's pearsonr: 0.1374
# [300]	valid_0's rmse: 0.894682	valid_0's pearsonr: 0.137485
# [320]	valid_0's rmse: 0.894646	valid_0's pearsonr: 0.137751
# [340]	valid_0's rmse: 0.894589	valid_0's pearsonr: 0.138188
# [360]	valid_0's rmse: 0.894575	valid_0's pearsonr: 0.138287
# [380]	valid_0's rmse: 0.894563	valid_0's pearsonr: 0.138376
# [400]	valid_0's rmse: 0.894558	valid_0's pearsonr: 0.138421
# [420]	valid_0's rmse: 0.894546	valid_0's pearsonr: 0.13853
# [440]	valid_0's rmse: 0.894503	valid_0's pearsonr: 0.138894
# [460]	valid_0's rmse: 0.894473	valid_0's pearsonr: 0.139145
# [480]	valid_0's rmse: 0.894489	valid_0's pearsonr: 0.139056
# [500]	valid_0's rmse: 0.894499	valid_0's pearsonr: 0.139022
# Early stopping, best iteration is:
# [456]	valid_0's rmse: 0.894456	valid_0's pearsonr: 0.139274
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 2364296, number of used features: 300
# [LightGBM] [Info] Start training from score -0.024609
# Training until validation scores don't improve for 50 rounds
# [20]	valid_0's rmse: 0.906134	valid_0's pearsonr: 0.108812
# [40]	valid_0's rmse: 0.904641	valid_0's pearsonr: 0.117231
# [60]	valid_0's rmse: 0.903862	valid_0's pearsonr: 0.122744
# [80]	valid_0's rmse: 0.903355	valid_0's pearsonr: 0.126255
# [100]	valid_0's rmse: 0.902987	valid_0's pearsonr: 0.128671
# [120]	valid_0's rmse: 0.902756	valid_0's pearsonr: 0.129899
# [140]	valid_0's rmse: 0.902472	valid_0's pearsonr: 0.131824
# [160]	valid_0's rmse: 0.902212	valid_0's pearsonr: 0.133627
# [180]	valid_0's rmse: 0.90202	valid_0's pearsonr: 0.134912
# [200]	valid_0's rmse: 0.901875	valid_0's pearsonr: 0.135867
# [220]	valid_0's rmse: 0.901739	valid_0's pearsonr: 0.136749
# [240]	valid_0's rmse: 0.901653	valid_0's pearsonr: 0.137212
# [260]	valid_0's rmse: 0.901612	valid_0's pearsonr: 0.137347
# [280]	valid_0's rmse: 0.901536	valid_0's pearsonr: 0.137833
# [300]	valid_0's rmse: 0.901493	valid_0's pearsonr: 0.138053
# [320]	valid_0's rmse: 0.901479	valid_0's pearsonr: 0.138081
# [340]	valid_0's rmse: 0.901453	valid_0's pearsonr: 0.138237
# [360]	valid_0's rmse: 0.901413	valid_0's pearsonr: 0.138503
# [380]	valid_0's rmse: 0.901394	valid_0's pearsonr: 0.138619
# [400]	valid_0's rmse: 0.901375	valid_0's pearsonr: 0.138752
# [420]	valid_0's rmse: 0.901353	valid_0's pearsonr: 0.138919
# [440]	valid_0's rmse: 0.90139	valid_0's pearsonr: 0.138638
# [460]	valid_0's rmse: 0.901349	valid_0's pearsonr: 0.138964
# [480]	valid_0's rmse: 0.901347	valid_0's pearsonr: 0.139003
# [500]	valid_0's rmse: 0.901352	valid_0's pearsonr: 0.138986
# [520]	valid_0's rmse: 0.901388	valid_0's pearsonr: 0.138745
# Early stopping, best iteration is:
# [486]	valid_0's rmse: 0.901332	valid_0's pearsonr: 0.13912
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 1995404, number of used features: 300
# [LightGBM] [Info] Start training from score -0.026871
# Training until validation scores don't improve for 50 rounds
# [20]	valid_0's rmse: 0.94026	valid_0's pearsonr: 0.0959005
# [40]	valid_0's rmse: 0.939091	valid_0's pearsonr: 0.103658
# [60]	valid_0's rmse: 0.938496	valid_0's pearsonr: 0.108438
# [80]	valid_0's rmse: 0.938011	valid_0's pearsonr: 0.112624
# [100]	valid_0's rmse: 0.937527	valid_0's pearsonr: 0.116862
# [120]	valid_0's rmse: 0.937173	valid_0's pearsonr: 0.119742
# [140]	valid_0's rmse: 0.936905	valid_0's pearsonr: 0.121848
# [160]	valid_0's rmse: 0.936696	valid_0's pearsonr: 0.123409
# [180]	valid_0's rmse: 0.936518	valid_0's pearsonr: 0.124763
# [200]	valid_0's rmse: 0.936353	valid_0's pearsonr: 0.126043
# [220]	valid_0's rmse: 0.936215	valid_0's pearsonr: 0.127088
# [240]	valid_0's rmse: 0.936094	valid_0's pearsonr: 0.128008
# [260]	valid_0's rmse: 0.936015	valid_0's pearsonr: 0.128618
# [280]	valid_0's rmse: 0.93588	valid_0's pearsonr: 0.12968
# [300]	valid_0's rmse: 0.93583	valid_0's pearsonr: 0.130084
# [320]	valid_0's rmse: 0.935772	valid_0's pearsonr: 0.130543
# [340]	valid_0's rmse: 0.935696	valid_0's pearsonr: 0.131153
# [360]	valid_0's rmse: 0.935711	valid_0's pearsonr: 0.131062
# [380]	valid_0's rmse: 0.935594	valid_0's pearsonr: 0.131999
# [400]	valid_0's rmse: 0.935601	valid_0's pearsonr: 0.131979
# [420]	valid_0's rmse: 0.935556	valid_0's pearsonr: 0.132348
# [440]	valid_0's rmse: 0.935552	valid_0's pearsonr: 0.132417
# [460]	valid_0's rmse: 0.935514	valid_0's pearsonr: 0.132756
# [480]	valid_0's rmse: 0.935461	valid_0's pearsonr: 0.133204
# [500]	valid_0's rmse: 0.935469	valid_0's pearsonr: 0.133179
# [520]	valid_0's rmse: 0.935427	valid_0's pearsonr: 0.133534
# [540]	valid_0's rmse: 0.935397	valid_0's pearsonr: 0.133815
# [560]	valid_0's rmse: 0.935378	valid_0's pearsonr: 0.13401
# [580]	valid_0's rmse: 0.935335	valid_0's pearsonr: 0.134397
# [600]	valid_0's rmse: 0.935337	valid_0's pearsonr: 0.134429
# [620]	valid_0's rmse: 0.935345	valid_0's pearsonr: 0.134425
# Early stopping, best iteration is:
# [583]	valid_0's rmse: 0.935323	valid_0's pearsonr: 0.134488
# n_iterations: 508

# %%
metrics
# Out:
# {'corr_mean': [0.13886058936146667, 0.13755397942885683, 0.13407055331307152],
#  'corr_std': [0.07915414826325932, 0.07698825419610046, 0.09028114654013825],
#  'error_mean': [0.8938671290153998, 0.9008497416944228, 0.9349246335759703],
#  'error_std': [0.036041653469375476,
#   0.03288339278155817,
#   0.024683867506234896]}

# %%
# mean corr on validation
np.mean(metrics["corr_mean"])
# Out:
# 0.13682837403446502

# %%
# mean rmse on validation
np.mean(metrics["error_mean"])
# Out:
# 0.9098805014285977

# %% [markdown]
# ***
# ## model training

# %%
seeds = [2,7,11,19,23]
models = list()

for seed in seeds:
    model_params["seed"] = seed
    
    train_dset = lgb.Dataset(
        data=features,
        label=target.target.values,
        free_raw_data=True
    )
    model = lgb.train(
        params=model_params,
        train_set=train_dset,
        num_boost_round=n_iterations,
        valid_sets=[train_dset,],
        early_stopping_rounds=10*n_iterations,
        verbose_eval=20,
        feval=pearsonr,
    )
    models.append(model)

    lgb.plot_importance(model, figsize=(8,15), importance_type="split", max_num_features=30)
    lgb.plot_importance(model, figsize=(8,15), importance_type="gain", max_num_features=30)
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 5080 rounds
# [20]	training's rmse: 0.913979	training's pearsonr: 0.132848
# [40]	training's rmse: 0.911541	training's pearsonr: 0.145523
# [60]	training's rmse: 0.909881	training's pearsonr: 0.157007
# [80]	training's rmse: 0.908413	training's pearsonr: 0.16778
# [100]	training's rmse: 0.90719	training's pearsonr: 0.176242
# [120]	training's rmse: 0.906019	training's pearsonr: 0.184025
# [140]	training's rmse: 0.904932	training's pearsonr: 0.191215
# [160]	training's rmse: 0.90394	training's pearsonr: 0.197526
# [180]	training's rmse: 0.902941	training's pearsonr: 0.203997
# [200]	training's rmse: 0.901975	training's pearsonr: 0.209977
# [220]	training's rmse: 0.901102	training's pearsonr: 0.215296
# [240]	training's rmse: 0.90024	training's pearsonr: 0.220526
# [260]	training's rmse: 0.899392	training's pearsonr: 0.225488
# [280]	training's rmse: 0.898558	training's pearsonr: 0.230397
# [300]	training's rmse: 0.897772	training's pearsonr: 0.234868
# [320]	training's rmse: 0.897012	training's pearsonr: 0.239158
# [340]	training's rmse: 0.896286	training's pearsonr: 0.243297
# [360]	training's rmse: 0.89562	training's pearsonr: 0.246811
# [380]	training's rmse: 0.894941	training's pearsonr: 0.250553
# [400]	training's rmse: 0.894254	training's pearsonr: 0.254315
# [420]	training's rmse: 0.893605	training's pearsonr: 0.257969
# [440]	training's rmse: 0.892964	training's pearsonr: 0.261351
# [460]	training's rmse: 0.892323	training's pearsonr: 0.264806
# [480]	training's rmse: 0.891698	training's pearsonr: 0.268101
# [500]	training's rmse: 0.891137	training's pearsonr: 0.270996
# Did not meet early stopping. Best iteration is:
# [508]	training's rmse: 0.890902	training's pearsonr: 0.272183
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 5080 rounds
# [20]	training's rmse: 0.913965	training's pearsonr: 0.133689
# [40]	training's rmse: 0.911512	training's pearsonr: 0.145506
# [60]	training's rmse: 0.90985	training's pearsonr: 0.156984
# [80]	training's rmse: 0.908444	training's pearsonr: 0.167069
# [100]	training's rmse: 0.907185	training's pearsonr: 0.176017
# [120]	training's rmse: 0.906014	training's pearsonr: 0.184074
# [140]	training's rmse: 0.904918	training's pearsonr: 0.191416
# [160]	training's rmse: 0.903901	training's pearsonr: 0.198041
# [180]	training's rmse: 0.902871	training's pearsonr: 0.204639
# [200]	training's rmse: 0.901939	training's pearsonr: 0.210407
# [220]	training's rmse: 0.901003	training's pearsonr: 0.216197
# [240]	training's rmse: 0.900137	training's pearsonr: 0.22123
# [260]	training's rmse: 0.899253	training's pearsonr: 0.226585
# [280]	training's rmse: 0.898434	training's pearsonr: 0.231423
# [300]	training's rmse: 0.89765	training's pearsonr: 0.23579
# [320]	training's rmse: 0.896921	training's pearsonr: 0.239829
# [340]	training's rmse: 0.896193	training's pearsonr: 0.243943
# [360]	training's rmse: 0.89545	training's pearsonr: 0.247875
# [380]	training's rmse: 0.89476	training's pearsonr: 0.251754
# [400]	training's rmse: 0.894109	training's pearsonr: 0.25522
# [420]	training's rmse: 0.893448	training's pearsonr: 0.258797
# [440]	training's rmse: 0.892836	training's pearsonr: 0.261998
# [460]	training's rmse: 0.892194	training's pearsonr: 0.265407
# [480]	training's rmse: 0.89159	training's pearsonr: 0.268525
# [500]	training's rmse: 0.891008	training's pearsonr: 0.271502
# Did not meet early stopping. Best iteration is:
# [508]	training's rmse: 0.890764	training's pearsonr: 0.272862
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 5080 rounds
# [20]	training's rmse: 0.913993	training's pearsonr: 0.133052
# [40]	training's rmse: 0.911571	training's pearsonr: 0.145083
# [60]	training's rmse: 0.909882	training's pearsonr: 0.156753
# [80]	training's rmse: 0.908438	training's pearsonr: 0.167287
# [100]	training's rmse: 0.907172	training's pearsonr: 0.176147
# [120]	training's rmse: 0.906006	training's pearsonr: 0.184309
# [140]	training's rmse: 0.9049	training's pearsonr: 0.191521
# [160]	training's rmse: 0.903822	training's pearsonr: 0.198615
# [180]	training's rmse: 0.902807	training's pearsonr: 0.20504
# [200]	training's rmse: 0.901888	training's pearsonr: 0.210666
# [220]	training's rmse: 0.900962	training's pearsonr: 0.216248
# [240]	training's rmse: 0.900085	training's pearsonr: 0.221432
# [260]	training's rmse: 0.899238	training's pearsonr: 0.226409
# [280]	training's rmse: 0.898405	training's pearsonr: 0.231341
# [300]	training's rmse: 0.897615	training's pearsonr: 0.235678
# [320]	training's rmse: 0.896852	training's pearsonr: 0.240059
# [340]	training's rmse: 0.896179	training's pearsonr: 0.243854
# [360]	training's rmse: 0.895479	training's pearsonr: 0.247698
# [380]	training's rmse: 0.894751	training's pearsonr: 0.251727
# [400]	training's rmse: 0.894085	training's pearsonr: 0.255304
# [420]	training's rmse: 0.893479	training's pearsonr: 0.258621
# [440]	training's rmse: 0.892873	training's pearsonr: 0.261774
# [460]	training's rmse: 0.892282	training's pearsonr: 0.264862
# [480]	training's rmse: 0.891701	training's pearsonr: 0.268001
# [500]	training's rmse: 0.89111	training's pearsonr: 0.271127
# Did not meet early stopping. Best iteration is:
# [508]	training's rmse: 0.890873	training's pearsonr: 0.272311
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 5080 rounds
# [20]	training's rmse: 0.913965	training's pearsonr: 0.131638
# [40]	training's rmse: 0.911576	training's pearsonr: 0.144502
# [60]	training's rmse: 0.909931	training's pearsonr: 0.15603
# [80]	training's rmse: 0.908478	training's pearsonr: 0.166751
# [100]	training's rmse: 0.907213	training's pearsonr: 0.17578
# [120]	training's rmse: 0.906059	training's pearsonr: 0.183864
# [140]	training's rmse: 0.904953	training's pearsonr: 0.191128
# [160]	training's rmse: 0.903902	training's pearsonr: 0.197864
# [180]	training's rmse: 0.902899	training's pearsonr: 0.204132
# [200]	training's rmse: 0.901948	training's pearsonr: 0.21018
# [220]	training's rmse: 0.901003	training's pearsonr: 0.216077
# [240]	training's rmse: 0.900154	training's pearsonr: 0.221207
# [260]	training's rmse: 0.899297	training's pearsonr: 0.226081
# [280]	training's rmse: 0.898484	training's pearsonr: 0.230935
# [300]	training's rmse: 0.897699	training's pearsonr: 0.235417
# [320]	training's rmse: 0.896919	training's pearsonr: 0.239702
# [340]	training's rmse: 0.896203	training's pearsonr: 0.24375
# [360]	training's rmse: 0.895509	training's pearsonr: 0.247566
# [380]	training's rmse: 0.894818	training's pearsonr: 0.251337
# [400]	training's rmse: 0.894142	training's pearsonr: 0.255021
# [420]	training's rmse: 0.893433	training's pearsonr: 0.258826
# [440]	training's rmse: 0.89281	training's pearsonr: 0.262191
# [460]	training's rmse: 0.892206	training's pearsonr: 0.265417
# [480]	training's rmse: 0.891609	training's pearsonr: 0.268568
# [500]	training's rmse: 0.891027	training's pearsonr: 0.271644
# Did not meet early stopping. Best iteration is:
# [508]	training's rmse: 0.890811	training's pearsonr: 0.272748
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 3141410, number of used features: 300
# [LightGBM] [Info] Start training from score -0.021092
# Training until validation scores don't improve for 5080 rounds
# [20]	training's rmse: 0.913972	training's pearsonr: 0.132803
# [40]	training's rmse: 0.911561	training's pearsonr: 0.145355
# [60]	training's rmse: 0.909863	training's pearsonr: 0.15693
# [80]	training's rmse: 0.908461	training's pearsonr: 0.167043
# [100]	training's rmse: 0.907149	training's pearsonr: 0.176409
# [120]	training's rmse: 0.906021	training's pearsonr: 0.184315
# [140]	training's rmse: 0.904871	training's pearsonr: 0.192063
# [160]	training's rmse: 0.903886	training's pearsonr: 0.198276
# [180]	training's rmse: 0.902858	training's pearsonr: 0.204535
# [200]	training's rmse: 0.901924	training's pearsonr: 0.210346
# [220]	training's rmse: 0.90098	training's pearsonr: 0.216196
# [240]	training's rmse: 0.900105	training's pearsonr: 0.221372
# [260]	training's rmse: 0.899299	training's pearsonr: 0.226031
# [280]	training's rmse: 0.898503	training's pearsonr: 0.230605
# [300]	training's rmse: 0.897707	training's pearsonr: 0.235077
# [320]	training's rmse: 0.896929	training's pearsonr: 0.239568
# [340]	training's rmse: 0.896176	training's pearsonr: 0.243698
# [360]	training's rmse: 0.895456	training's pearsonr: 0.247736
# [380]	training's rmse: 0.894767	training's pearsonr: 0.25155
# [400]	training's rmse: 0.894104	training's pearsonr: 0.255139
# [420]	training's rmse: 0.893468	training's pearsonr: 0.258582
# [440]	training's rmse: 0.892873	training's pearsonr: 0.261705
# [460]	training's rmse: 0.892252	training's pearsonr: 0.265022
# [480]	training's rmse: 0.891685	training's pearsonr: 0.267987
# [500]	training's rmse: 0.8911	training's pearsonr: 0.271044
# Did not meet early stopping. Best iteration is:
# [508]	training's rmse: 0.890887	training's pearsonr: 0.272169

# %%
for seed,model in zip(seeds,models): 
    model.save_model(f"../ump-artifacts/lgbm-linear/lgbm-seed{seed}.txt")

# %% [markdown]
# ***
# ## inference

# %%
if current_env == "kaggle":

    import ubiquant
    env = ubiquant.make_env()  
    iter_test = env.iter_test()
    
    features = [f"f_{i}" for i in range(300)]
    for (test_df, sample_prediction_df) in iter_test:  
        preds = [model.predict(test_df[features]) for model in models]
        sample_prediction_df['target'] = np.mean(preds, axis=0)
        env.predict(sample_prediction_df) 
        display(sample_prediction_df)

# %% [markdown]
# ***
